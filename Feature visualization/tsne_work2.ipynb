# %%
import keras
print(keras.__version__)

import tensorflow
print(tensorflow.__version__)
# Out:
# 2.12.0
# 2.12.0

# %%
pip install mlxtend --upgrade --no-deps
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# ...

# %%
import mlxtend                                                        
print(mlxtend.__version__)
# Out:
# 0.22.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! pip install tsne==0.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tsne: filename=tsne-0.2.0-cp310-cp310-linux_x86_64.whl size=272170 sha256=67506e0bef141469df49756df7418d3f98d2b27ae853872b62608ea95fc47a2b
#   Stored in directory: /root/.cache/pip/wheels/b9/e5/cf/1d3a793ba20c2078c58d2398de7dc7664b3830a22b204d65d4
# Successfully built tsne
# ...

# %%
import tsne

# %%
import numpy as np
from numpy.random import RandomState
np.random.seed(1)

from tsne import bh_sne
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt

import os
import os.path
import glob

from keras.preprocessing import image

# %%
x = np.load("/path to features/feature_l16_12000_for_tsne.npy")
y = np.load("path to feature/label_l16_12000_for_tsne.npy")

# %%
list_fams = ['gan', 'graphics', 'real']
list_fams
# Out:
# ['gan', 'graphics', 'real']

# %%
print("Running t-SNE ...")
tsne_x = bh_sne(np.float64(x), d=2, perplexity=30., theta=0.5, random_state=RandomState(1))

np.save("path to features/tsne_l16_x.npy", tsne_x)
tsne_x.shape
# Out:
# Running t-SNE ...
# (12000, 2)

# %%
#tsne_x = np.load("path to file/tsne_x.npy")

# %%
print("Plotting t-SNE ...")
figure = plt.gcf()
figure.set_size_inches(20, 17)
plt.scatter(tsne_x[y.astype(int)==0, 0], tsne_x[y.astype(int)==0, 1], c='green', marker='o', edgecolors="black", label="GAN")
plt.scatter(tsne_x[y.astype(int)==1, 0], tsne_x[y.astype(int)==1, 1], c='white', marker='s', edgecolors="blue", label="Graphics")
plt.scatter(tsne_x[y.astype(int)==2, 0], tsne_x[y.astype(int)==2, 1], c='red', marker='D', edgecolors="pink", label="Real")
plt.clim(-0.5, len(list_fams)-0.5)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
frame1.axes.yaxis.set_ticklabels([])
frame1.axes.get_xaxis().set_visible(False)
frame1.axes.get_yaxis().set_visible(False)
plt.legend(loc="upper right", prop={'size': 35})
plt.savefig('/content/gdrive/MyDrive/programs/tsne/TSNE_features_l16_20_17.jpg', format='jpg')                 
plt.show()
# Out:
# Plotting t-SNE ...
